# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df =  pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/TelecomCustomerChurn.csv')

# %%
df.sample(5)
# Out:
#       customerID  Gender  SeniorCitizen Partner Dependents  Tenure  \
# 5636  0601-WZHJF    Male              0     Yes         No      14
# 2928  1930-QPBVZ    Male              0     Yes        Yes      68
# 3529  2880-FPNAE    Male              1     Yes         No       2
# 1255  4030-VPZBD  Female              0      No         No       2
# 3821  1833-VGRUM  Female              1      No         No       1
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 5636           No            No             DSL             No  ...
# 2928          Yes            No     Fiber optic            Yes  ...
# 3529          Yes            No     Fiber optic             No  ...
# 1255           No            No             DSL             No  ...
# 3821          Yes           Yes     Fiber optic             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 5636               No          No         Yes             Yes   Monthly
# ...

# %%
def datapreparation(df):
    
    df.drop(["customerID"], inplace = True, axis = 1)
    
    for col in df.select_dtypes(include='object').columns:
        df[col] = df[col].str.strip()
    
    df.TotalCharges = df.TotalCharges.replace(" ", np.nan)
    df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')
    df.TotalCharges.fillna(0, inplace=True)
    
    cols1 = ['Partner', 'Dependents', 'PaperlessBilling', 'Churn', 'PhoneService']
    for col in cols1:
        df[col] = df[col].apply(lambda x: 0 if x == "No" else 1)
   
    df.Gender = df.Gender.apply(lambda x: 0 if x == "Male" else 1)
    
    df.MultipleLines = df.MultipleLines.map({
        'No phone service': 0,
        'No': 0,
        'Yes': 1
    })
    
    cols2 = [
        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
        'TechSupport', 'StreamingTV', 'StreamingMovies'
    ]
    
    for col in cols2:
        df[col] = df[col].map({
            'No internet service': 0,
            'No': 0,
            'Yes': 1
        })
    
    df = pd.get_dummies(
        df,
        columns=['InternetService', 'Contract', 'PaymentMethod'],
        drop_first=True,
        dtype=int
    )
    
    return df

# %%
df = datapreparation(df)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 7043 non-null   int64
#  1   SeniorCitizen                          7043 non-null   int64
#  2   Partner                                7043 non-null   int64
#  3   Dependents                             7043 non-null   int64
#  4   Tenure                                 7043 non-null   int64
#  5   PhoneService                           7043 non-null   int64
#  6   MultipleLines                          7043 non-null   int64
#  7   OnlineSecurity                         7043 non-null   int64
#  8   OnlineBackup                           7043 non-null   int64
#  9   DeviceProtection                       7043 non-null   int64
#  10  TechSupport                            7043 non-null   int64
# ...

# %%
df.head()
# Out:
#    Gender  SeniorCitizen  Partner  Dependents  Tenure  PhoneService  \
# 0       1              0        1           0       1             0
# 1       0              0        0           0      34             1
# 2       0              0        0           0       2             1
# 3       0              0        0           0      45             0
# 4       1              0        0           0       2             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 0              0               0             1                 0  ...
# 1              0               1             0                 1  ...
# 2              0               1             1                 0  ...
# 3              0               1             0                 1  ...
# 4              0               0             0                 0  ...
#
#    PaperlessBilling  MonthlyCharges  TotalCharges  Churn  \
# 0                 1           29.85         29.85      0
# ...

# %% [markdown]
# ### Building the Model

# %% [markdown]
# Since this is a classificaton type problem, I am thinking to use Random Forest as my model, I think it is gonna perform best. (i am also going to experiment with some other models too.)

# %%
from sklearn.model_selection import train_test_split,  cross_val_score, GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import roc_auc_score, roc_curve, precision_score, f1_score, recall_score
from sklearn.ensemble import RandomForestClassifier

# %%
X = df.drop('Churn', axis=1)
y = df['Churn']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=5, stratify=y
)

# %%
def evaluate_model(model, X_train, y_train, X_test, y_test, feature_names=None):
    
    # ------------------ Train ------------------
    model.fit(X_train, y_train)
    
    # ------------------ Predictions ------------------
    y_pred = model.predict(X_test)
    
    # Probabilities (for ROC)
    y_prob = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else None
    
    # ------------------ Metrics ------------------
    print(f"Model: {model.__class__.__name__}")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("\nClassification Report:\n", classification_report(y_test, y_pred))
    
    # ------------------ Confusion Matrix + ROC ------------------
    plt.figure(figsize=(10,4))
    
    # Confusion Matrix
    plt.subplot(1,2,1)
    sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", cmap="Blues")
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    
    # ROC Curve
    if y_prob is not None:
        auc = roc_auc_score(y_test, y_prob)
        fpr, tpr, _ = roc_curve(y_test, y_prob)
        
        plt.subplot(1,2,2)
        plt.plot(fpr, tpr, label=f"AUC = {auc:.3f}")
        plt.plot([0,1], [0,1], linestyle="--")
        plt.title("ROC Curve")
        plt.xlabel("FPR")
        plt.ylabel("TPR")
        plt.legend()
        
        print("ROC-AUC:", auc)
    
    plt.tight_layout()
    plt.show()
    
    # ------------------ Feature Importance  ------------------
    if feature_names is None:
        print("Feature names not provided. Skipping feature importance plot.")
        return
    
    # Get importance safely
    if hasattr(model, "coef_"):
        importance = model.coef_.ravel()
    elif hasattr(model, "feature_importances_"):
        importance = model.feature_importances_
    else:
        print("Model does not support feature importance.")
        return
    
    # Create dataframe 
    feat_imp = pd.DataFrame({
        "feature": feature_names,
        "importance": importance
    }).sort_values(by="importance", ascending=False)
    
    # Plotting
    plt.figure(figsize=(12,6))
    sns.barplot(
        data=feat_imp,
        x="importance",
        y="feature"
    )
    
    plt.title("Feature Importances")
    plt.xlabel("Importance")
    plt.ylabel("Features")
    plt.tight_layout()
    plt.show()
    plt.show()

# %% [markdown]
# ### Hyper Parameter tuning

# %% [markdown]
# ####  Grid 1 : going to select the estimator

# %%
param_grid_1 = {
    'n_estimators': [100, 200, 300, 500]
}

rf = RandomForestClassifier(random_state=5)

grid_1 = GridSearchCV(
    estimator=rf,
    param_grid=param_grid_1,
    scoring='roc_auc',
    cv=5,
    verbose=1,
    n_jobs=-1
)
grid_1.fit(X_train , y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=5), n_jobs=-1,
#              param_grid={'n_estimators': [100, 200, 300, 500]},
#              scoring='roc_auc', verbose=1)

# %%
grid_1.best_estimator_
# Out:
# RandomForestClassifier(n_estimators=500, random_state=5)

# %%
grid_1.best_score_
# Out:
# np.float64(0.8287216610320028)

# %% [markdown]
# #### Grid 2 : selecting param_grid_2 = max_depth , min_samples_split , min_samples_leaf

# %%
param_grid_2 = {
    'max_depth': [None, 5, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5]
}

rf = RandomForestClassifier(random_state=5)

grid_2 = GridSearchCV(
    estimator=rf,
    param_grid=param_grid_2,
    scoring='roc_auc',
    cv=5,
    verbose=1,
    n_jobs=-1
)
grid_2.fit(X_train , y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=5), n_jobs=-1,
#              param_grid={'max_depth': [None, 5, 10, 20],
#                          'min_samples_leaf': [1, 2, 5],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='roc_auc', verbose=1)

# %%
grid_2.best_estimator_
# Out:
# RandomForestClassifier(max_depth=5, min_samples_split=10, random_state=5)

# %%
grid_2.best_score_
# Out:
# np.float64(0.8467103491676221)

# %% [markdown]
# #### Grid 3 : selecting max_feartures

# %%
param_grid_3 = {
    'max_features': ['sqrt', 'log2', 0.5, 0.7]
}
rf = RandomForestClassifier(random_state=5)

grid_3= GridSearchCV(
    estimator=rf,
    param_grid=param_grid_3,
    scoring='roc_auc',
    cv=5,
    verbose=1,
    n_jobs=-1
)
grid_3.fit(X_train , y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=5), n_jobs=-1,
#              param_grid={'max_features': ['sqrt', 'log2', 0.5, 0.7]},
#              scoring='roc_auc', verbose=1)

# %%
grid_3.best_estimator_
# Out:
# RandomForestClassifier(random_state=5)

# %%
grid_3.best_score_
# Out:
# np.float64(0.8272604184613751)

# %% [markdown]
# #### grid 4 : class_weight , max_samples, bootstrap  (deals with class imbalance , and sampling strategy)

# %%
param_grid_4 = {
    'class_weight': [None, 'balanced'],
    'bootstrap': [True],
    'max_samples': [0.7, 0.8, 1.0]
}
f = RandomForestClassifier(random_state=5)

grid_4= GridSearchCV(
    estimator=rf,
    param_grid=param_grid_4,
    scoring='roc_auc',
    cv=5,
    verbose=1,
    n_jobs=-1
)
grid_4.fit(X_train , y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=5), n_jobs=-1,
#              param_grid={'bootstrap': [True],
#                          'class_weight': [None, 'balanced'],
#                          'max_samples': [0.7, 0.8, 1.0]},
#              scoring='roc_auc', verbose=1)

# %%
grid_4.best_estimator_
# Out:
# RandomForestClassifier(max_samples=0.8, random_state=5)

# %%
grid_4.best_score_
# Out:
# np.float64(0.8315071248245772)

# %% [markdown]
# #### Final grid

# %%
param_grid_final = {
    'n_estimators': [100, 200],
    'max_depth': [4, 5, 6],
    'min_samples_split': [8, 10, 12],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt', 0.5],
    'class_weight': [None, 'balanced']
}

rf = RandomForestClassifier(random_state=5)

final_grid = GridSearchCV(
    estimator=rf,
    param_grid=param_grid_final,
    scoring='roc_auc',
    cv=5,
    n_jobs=-1,
    verbose=1
)

final_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=5), n_jobs=-1,
#              param_grid={'class_weight': [None, 'balanced'],
#                          'max_depth': [4, 5, 6], 'max_features': ['sqrt', 0.5],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [8, 10, 12],
#                          'n_estimators': [100, 200]},
#              scoring='roc_auc', verbose=1)

# %%
final_grid.best_estimator_
# Out:
# RandomForestClassifier(max_depth=6, min_samples_split=8, n_estimators=200,
#                        random_state=5)

# %%
final_grid.best_score_
# Out:
# np.float64(0.8478880617690813)

# %%
model = final_grid.best_estimator_

# %% [markdown]
# ### final model

# %%
evaluate_model(model, X_train , y_train, X_test, y_test, feature_names = X_train.columns)
# Out:
# Model: RandomForestClassifier
# Accuracy: 0.7841930903928065
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86      1552
#            1       0.65      0.40      0.50       561
#
#     accuracy                           0.78      2113
#    macro avg       0.73      0.66      0.68      2113
# weighted avg       0.77      0.78      0.77      2113
#
# ROC-AUC: 0.8389066146608597
